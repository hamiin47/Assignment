# %% [markdown]
# <a href="https://colab.research.google.com/github/hamiin47/Assignment/blob/main/YB_9_20_%EC%84%B8%EC%85%98_%EB%AC%B8%EC%A0%9C_scores_Exercises.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Scores

# %% [markdown]
# ### Introduction:
#
# This time you will create the data.
#
# ***Exercise based on [Chris Albon](http://chrisalbon.com/) work, the credits belong to him.***
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
from collections import Counter
import seaborn as sns

# set this so the graphs open internally
# %matplotlib inline

# %% [markdown]
# ### Step 2. Create the DataFrame that should look like the one below.
# *참고*
#
# ```
# raw_data = {'first_name': ['Jason', 'Molly', 'Tina', 'Jake', 'Amy'],
#             'last_name': ['Miller', 'Jacobson', 'Ali', 'Milner', 'Cooze'],
#             'female': [0, 1, 1, 0, 1],
#             'age': [42, 52, 36, 24, 73],
#             'preTestScore': [4, 24, 31, 2, 3],
#             'postTestScore': [25, 94, 57, 62, 70]}
# ```

# %%
raw_data = {'first_name': ['Jason', 'Molly', 'Tina', 'Jake', 'Amy'],
            'last_name': ['Miller', 'Jacobson', 'Ali', 'Milner', 'Cooze'],
            'female': [0, 1, 1, 0, 1],
            'age': [42, 52, 36, 24, 73],
            'preTestScore': [4, 24, 31, 2, 3],
            'postTestScore': [25, 94, 57, 62, 70]}

df = pd.DataFrame(raw_data)
df
# Out:
#   first_name last_name  female  age  preTestScore  postTestScore
# 0      Jason    Miller       0   42             4             25
# 1      Molly  Jacobson       1   52            24             94
# 2       Tina       Ali       1   36            31             57
# 3       Jake    Milner       0   24             2             62
# 4        Amy     Cooze       1   73             3             70

# %% [markdown]
# ### Step 3. Create a Scatterplot of preTestScore and postTestScore, with the size of each point determined by age
# #### Hint: Don't forget to place the labels

# %%
plt.figure(figsize=(10,6))
plt.scatter(df['preTestScore'], df['postTestScore'], s=df['age']*10, alpha=0.5)

plt.title('Scatterplot of PreTestScore vs PostTestScore', fontsize=15)
plt.xlabel('preTest Score', fontsize=12)
plt.ylabel('postTest Score', fontsize=12)

plt.show()

# %% [markdown]
# ### Step 4. Create a Scatterplot of preTestScore and postTestScore.
# ### This time the size should be 4.5 times the postTestScore and the color determined by sex

# %%
plt.figure(figsize=(10,6))

sns.scatterplot(
    x='preTestScore',
    y='postTestScore',
    size=df['postTestScore'] * 4.5,
    hue='female',
    palette={0: 'blue', 1: 'pink'},
    data=df,
    alpha=0.6
)

plt.title('Scatterplot of preTestScore vs postTestScore', fontsize=15)
plt.xlabel('preTestScore', fontsize=12)
plt.ylabel('postTestScore', fontsize=12)

plt.show()

# %% [markdown]
# ### BONUS: Create your own question and answer it.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# 박스 플롯 생성: 성별에 따른 나이 분포
sns.boxplot(x='female', y='age', data=df)
plt.title('Age distribution by gender')
plt.xlabel('Female (1: Female, 0: Male)')
plt.ylabel('Age')
plt.show()
